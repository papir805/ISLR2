# %% [markdown]
# # Presentation

# %%
import gensim
from gensim.models.keyedvectors import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format("~/Downloads/GoogleNews-vectors-negative300.bin", binary=True)

# %%
woman_plus_king_minus_man = model.most_similar(positive=['woman', 'king'], negative=['man'])

# %%
woman_plus_king_minus_man
# Out:
# [('queen', 0.7118193507194519),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321839332581),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.5181134343147278),
#  ('sultan', 0.5098593831062317),
#  ('monarchy', 0.5087411999702454)]

# %%
model.most_similar(positive=['Washington', 'Spain'], negative=['America'], topn=10)
# Out:
# [('Madrid', 0.5503379106521606),
#  ('Barcelona', 0.4633202850818634),
#  ('Valencia', 0.4554997384548187),
#  ('Daniel_Wools', 0.42950066924095154),
#  ('San_Joan_Despi', 0.42777788639068604),
#  ('Malaga', 0.4263588488101959),
#  ('Esplugues_de_Llobregat', 0.4247756600379944),
#  ('Winterthur_FC', 0.4213378131389618),
#  ('Nestor_Ikeda', 0.4192081093788147),
#  ('ZONAS_Europa_DIARY', 0.4172571003437042)]

# %%
man = model.get_vector('man')
len(man)
# Out:
# 300

# %%
man
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
len(man)
# Out:
# 300

# %%
king = model.get_vector('king')

# %%
woman = model.get_vector('woman')

# %%
woman + king - man
# Out:
# array([ 4.29687500e-02, -1.78222656e-01, -1.29089355e-01,  1.15234375e-01,
#         2.68554688e-03, -1.02294922e-01,  1.95800781e-01, -1.79504395e-01,
#         1.95312500e-02,  4.09919739e-01, -3.68164062e-01, -3.96484375e-01,
#        -1.56738281e-01,  1.46484375e-03, -9.30175781e-02, -1.16455078e-01,
#        -5.51757812e-02, -1.07574463e-01,  7.91015625e-02,  1.98974609e-01,
#         2.38525391e-01,  6.34002686e-02, -2.17285156e-02,  0.00000000e+00,
#         4.72412109e-02, -2.17773438e-01, -3.44726562e-01,  6.37207031e-02,
#         3.16406250e-01, -1.97631836e-01,  8.59375000e-02, -8.11767578e-02,
#        -3.71093750e-02,  3.15551758e-01, -3.41796875e-01, -4.68750000e-02,
#         9.76562500e-02,  8.39843750e-02, -9.71679688e-02,  5.17578125e-02,
#        -5.00488281e-02, -2.20947266e-01,  2.29492188e-01,  1.26403809e-01,
#         2.49023438e-01,  2.09960938e-02, -1.09863281e-01,  5.81054688e-02,
# ...

# %%
model.most_similar('Madrid')
# Out:
# [('Barcelona', 0.7255445718765259),
#  ('Spain', 0.6743446588516235),
#  ('Bilbao', 0.6328346729278564),
#  ('Miguel_Arrastia', 0.6278631687164307),
#  ('Museo_Reina_Sofia', 0.6277922987937927),
#  ('Malaga', 0.6034683585166931),
#  ('Málaga', 0.6031717658042908),
#  ('Zaragoza', 0.601626455783844),
#  ('Catalan', 0.6015604734420776),
#  ('Seville', 0.5968208312988281)]

# %%
import numpy as np

# %%
np.linalg.norm((woman + king - man)/np.linalg.norm(woman + king - man))
# Out:
# 0.99999994

# %%
np.linalg.norm(np.array([1,1,1]))
# Out:
# 1.7320508075688772

# %%
toad = model.get_vector('toad')
toad
# Out:
# array([ 1.04492188e-01,  2.53906250e-01, -1.37695312e-01, -5.88989258e-03,
#        -1.55273438e-01, -1.81640625e-01, -3.63281250e-01,  2.18750000e-01,
#         1.82617188e-01,  1.03515625e-01,  2.34375000e-01, -3.88671875e-01,
#        -1.04492188e-01, -1.65039062e-01,  5.27343750e-02, -2.27050781e-02,
#        -9.91210938e-02,  1.95312500e-01,  2.24609375e-01, -6.83593750e-02,
#        -2.12890625e-01, -6.17675781e-02,  6.03027344e-02,  1.67968750e-01,
#        -1.40625000e-01, -1.79687500e-01, -1.84570312e-01,  2.02148438e-01,
#         2.79296875e-01, -7.26318359e-03,  2.22656250e-01,  1.24511719e-01,
#        -2.44140625e-02, -5.27343750e-02, -2.07031250e-01, -5.17578125e-02,
#         1.77734375e-01,  1.68945312e-01,  1.66992188e-01,  2.05078125e-01,
#         1.58203125e-01, -2.18750000e-01,  1.73828125e-01,  2.08007812e-01,
#        -1.13769531e-01, -2.83203125e-01,  6.05468750e-02, -7.42187500e-02,
# ...

# %%
toad.shape
# Out:
# (300,)

# %%
salamander = model.get_vector('salamander')
goldfish = model.get_vector('goldfish')

# %%
model.similarity('salamander', 'goldfish')
# Out:
# 0.30232808

# %%
model.similarity('salamander', 'toad')
# Out:
# 0.5928141

# %%
model.similarity('goldfish', 'toad')
# Out:
# 0.42403838

# %%
model.similarity('man', 'woman')
# Out:
# 0.76640123

# %%
model.similarity('man', 'madrid')
# Out:
# 0.10376482

# %%
import numpy as np

# %%
np.linalg.norm(man)
# Out:
# 2.3106172

# %%
np.linalg.norm(woman)
# Out:
# 2.655624

# %%
np.dot(man, woman) / (np.linalg.norm(man) * np.linalg.norm(woman))
# Out:
# 0.76640123

# %%
np.dot(salamander, toad) / (np.linalg.norm(salamander) * np.linalg.norm(toad))
# Out:
# 0.5928141

# %%
np.linalg.norm(salamander - toad)
# Out:
# 3.2557015

# %%
np.linalg.norm(salamander - goldfish)
# Out:
# 4.2965145
